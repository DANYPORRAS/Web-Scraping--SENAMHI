# %% [markdown]
# <font size = 6 color = 'green'> Web Scraping - SENAMHI
#
# <font size = 5 color = 'green'> Autor : Bach. Daniel A. Porras Nuñez

# %% [markdown]
# ## <font size = 5 color = 'black'> **Función de Web Scraping para exportar datos meteorologicos historico de las estaciones de SENAMHI**

# %%
# !pip install beautifulsoup4==4.12.3 certifi==2024.2.2 charset-normalizer==3.3.2 et-xmlfile==1.1.0 idna==3.6 lxml==5.1.0 numpy==1.26.4 openpyxl==3.1.2 pandas==2.2.0 python-dateutil==2.8.2 pytz==2024.1 requests==2.31.0 six==1.16.0 soupsieve==2.5 tzdata==2024.1 urllib3==2.2.0
# Out:
# Collecting beautifulsoup4==4.12.3
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting certifi==2024.2.2
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting charset-normalizer==3.3.2
#   Downloading charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting et-xmlfile==1.1.0
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting idna==3.6
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting lxml==5.1.0
#   Downloading lxml-5.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.5 kB)
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.9 MB/s eta 0:00:00
# Collecting openpyxl==3.1.2
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pandas==2.2.0
#   Downloading pandas-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting python-dateutil==2.8.2
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl.metadata (8.2 kB)
# Collecting pytz==2024.1
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting requests==2.31.0
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting six==1.16.0
#   Downloading six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting soupsieve==2.5
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting tzdata==2024.1
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting urllib3==2.2.0
#   Downloading urllib3-2.2.0-py3-none-any.whl.metadata (6.4 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 6.7 MB/s eta 0:00:00
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 13.3 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.3/140.3 kB 12.1 MB/s eta 0:00:00
# Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.8 MB/s eta 0:00:00
# Downloading lxml-5.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 80.1 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 95.8 MB/s eta 0:00:00
# Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 18.6 MB/s eta 0:00:00
# Downloading pandas-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 97.3 MB/s eta 0:00:00
# Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 18.3 MB/s eta 0:00:00
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 33.6 MB/s eta 0:00:00
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 5.3 MB/s eta 0:00:00
# Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 25.1 MB/s eta 0:00:00
# Downloading urllib3-2.2.0-py3-none-any.whl (120 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.9/120.9 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: pytz, urllib3, tzdata, soupsieve, six, numpy, lxml, idna, et-xmlfile, charset-normalizer, certifi, requests, python-dateutil, openpyxl, beautifulsoup4, pandas
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.2
#     Uninstalling tzdata-2025.2:
#       Successfully uninstalled tzdata-2025.2
#   Attempting uninstall: soupsieve
#     Found existing installation: soupsieve 2.7
#     Uninstalling soupsieve-2.7:
#       Successfully uninstalled soupsieve-2.7
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: lxml
#     Found existing installation: lxml 5.4.0
#     Uninstalling lxml-5.4.0:
#       Successfully uninstalled lxml-5.4.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: et-xmlfile
#     Found existing installation: et_xmlfile 2.0.0
#     Uninstalling et_xmlfile-2.0.0:
#       Successfully uninstalled et_xmlfile-2.0.0
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.4.2
#     Uninstalling charset-normalizer-3.4.2:
#       Successfully uninstalled charset-normalizer-3.4.2
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.7.14
#     Uninstalling certifi-2025.7.14:
#       Successfully uninstalled certifi-2025.7.14
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: openpyxl
#     Found existing installation: openpyxl 3.1.5
#     Uninstalling openpyxl-3.1.5:
#       Successfully uninstalled openpyxl-3.1.5
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.13.4
#     Uninstalling beautifulsoup4-4.13.4:
#       Successfully uninstalled beautifulsoup4-4.13.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.31.0 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# datasets 4.0.0 requires requests>=2.32.2, but you have requests 2.31.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed beautifulsoup4-4.12.3 certifi-2024.2.2 charset-normalizer-3.3.2 et-xmlfile-1.1.0 idna-3.6 lxml-5.1.0 numpy-1.26.4 openpyxl-3.1.2 pandas-2.2.0 python-dateutil-2.8.2 pytz-2024.1 requests-2.31.0 six-1.16.0 soupsieve-2.5 tzdata-2024.1 urllib3-2.2.0

# %%
import pkg_resources

libraries = [
    'beautifulsoup4', 'certifi', 'charset-normalizer', 'et-xmlfile', 'idna',
    'lxml', 'numpy', 'openpyxl', 'pandas', 'python-dateutil', 'pytz',
    'requests', 'six', 'soupsieve', 'tzdata', 'urllib3'
]

for lib in libraries:
    try:
        version = pkg_resources.get_distribution(lib).version
        print(f"{lib}: {version} (instalado correctamente)")
    except pkg_resources.DistributionNotFound:
        print(f"{lib}: No se encontró la librería")
# Out:
# /tmp/ipython-input-3542600907.py:1: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources
# beautifulsoup4: 4.12.3 (instalado correctamente)
# certifi: 2024.2.2 (instalado correctamente)
# charset-normalizer: 3.3.2 (instalado correctamente)
# et-xmlfile: 1.1.0 (instalado correctamente)
# idna: 3.6 (instalado correctamente)
# lxml: 5.1.0 (instalado correctamente)
# numpy: 1.26.4 (instalado correctamente)
# openpyxl: 3.1.2 (instalado correctamente)
# pandas: 2.2.0 (instalado correctamente)
# python-dateutil: 2.8.2 (instalado correctamente)
# pytz: 2024.1 (instalado correctamente)
# requests: 2.31.0 (instalado correctamente)
# six: 1.16.0 (instalado correctamente)
# soupsieve: 2.5 (instalado correctamente)
# tzdata: 2024.1 (instalado correctamente)
# urllib3: 2.2.0 (instalado correctamente)

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import os
import re

def stations():
    link = "https://www.senamhi.gob.pe/mapas/mapa-estaciones-2/"
    response = requests.get(link)
    stn_senamhi = BeautifulSoup(response.text, 'html.parser')

    stn_senamhi2 = re.split(r'nom', str(stn_senamhi))[1:]
    stn = []
    cat = []
    lat = []
    lon = []
    ico = []
    cod = []
    cod_old = []
    estado = []
    data_stn = []

    for i in range(len(stn_senamhi2)):
        x = stn_senamhi2[i].replace('"', '').replace(': ', ":").replace(',\n', "").replace('\}\{', "")
        data_estaciones = x.split(",")
        stn.append(data_estaciones[0].replace(":", ""))
        cat.append(data_estaciones[1].replace("cate:", ""))
        lat.append(data_estaciones[2].replace("lat:", ""))
        lon.append(data_estaciones[3].replace("lon:", ""))
        ico.append(data_estaciones[4].replace(" ico:", ""))
        cod.append(data_estaciones[5].replace(" cod:", "") if data_estaciones[5][:5] == " cod:" else None)
        cod_old.append(data_estaciones[6].replace("cod_old:", "") if data_estaciones[6][:8] == "cod_old:" else None)
        estado_value = data_estaciones[7] if len(data_estaciones) > 7 else data_estaciones[6]
        estado.append(estado_value.replace("}{", "").replace(" estado:", "") if estado_value[:8] == " estado:" else None)

        data_stn.append(pd.DataFrame({
            'estacion': stn[-1],
            'categoria': cat[-1],
            'lat': lat[-1],
            'lon': lon[-1],
            'ico': ico[-1],
            'cod': cod[-1],
            'cod_old': cod_old[-1],
            'estado': estado[-1]
        }, index=[0]))

    df_stns = pd.concat(data_stn, ignore_index=True)
    return df_stns

def senamhiws_info(code, stations, from_date=None, to_date=None, lat=None, lon=None, stc=None):
    if not code or not isinstance(code, str):
        print("Codigo no definido")
        return None

    df_history_senamhi = []

    if from_date is None and to_date is None:
        from_date = datetime(2016, 1, 1)
        to_date = datetime(2023, 12, 31)
    elif from_date is None and to_date is not None:
        from_date = datetime(2016, 1, 1)
    elif from_date is not None and to_date is None:
        to_date = datetime(2023, 12, 31)

    idx_cod = stations.index[stations['cod'] == code]
    df_idx_stn = stations.loc[idx_cod].reset_index(drop=True)

    ts_date = pd.date_range(from_date, to_date, freq='MS')
    tsw_date = ts_date.strftime('%Y%m')

    for j, date in enumerate(ts_date):
        if pd.isna(df_idx_stn['cod'][0]):
            link = f"https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones={df_idx_stn['cod'].iloc[0]}&CBOFiltro={tsw_date[j]}&t_e={df_idx_stn['ico'].iloc[0]}&estado={df_idx_stn['estado'].iloc[0]}&cod_old={df_idx_stn['cod_old'].iloc[0]}"
        else:
            link = f"https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones={df_idx_stn['cod'].iloc[0]}&CBOFiltro={tsw_date[j]}&t_e={df_idx_stn['ico'].iloc[0]}&estado={df_idx_stn['estado'].iloc[0]}"

        try:
            print(f"Descargando datos desde: {link}")
            data_stn_senamhi = pd.read_html(link)
        except ValueError as e:
            print(f"Error al leer HTML desde el enlace: {e}")
            print(f"El enlace que falló es: {link}")
            continue

        # Procesar los datos descargados
        data_df_history_senamhi = data_stn_senamhi[1]
        data_df_history_senamhi.columns = data_df_history_senamhi.iloc[0]
        data_df_history_senamhi = data_df_history_senamhi[1:]

        # Eliminar filas que contienen los encabezados repetidos
        data_df_history_senamhi = data_df_history_senamhi[data_df_history_senamhi.iloc[:, 0] != 'AÑO / MES / DÍA']

        # Añadir información adicional
        data_df_history_senamhi["estacion"] = stc
        data_df_history_senamhi["lat"] = lat
        data_df_history_senamhi["lon"] = lon

        # Añadir los datos al historial
        df_history_senamhi.append(data_df_history_senamhi)

    # Combinar todos los datos descargados en un único DataFrame
    if df_history_senamhi:
        df_combined = pd.concat(df_history_senamhi, ignore_index=True)
        output_filename = f"{code}_{df_idx_stn['estacion'].iloc[0]}_historico.xlsx"
        df_combined.to_excel(output_filename, index=False)
        print(f"Datos combinados guardados en: {output_filename}")
    else:
        print("No se encontraron datos para la estación especificada.")

    return df_history_senamhi

# %%
# Uso del código
stations_data = stations()
print(stations_data[stations_data["estacion"] == 'ANANEA'])
# Out:
#     estacion categoria        lat        lon ico     cod cod_old estado
# 569   ANANEA        CO   -14.6763   -69.5339   M  114050    None   REAL

# %%
# Filtrar datos de la estación específica
stations_data = stations()

stations_data = stations_data[stations_data["cod"] == '472CF72C']
print("aaaaa", stations_data.head())
# Out:
# aaaaa     estacion categoria         lat         lon ico       cod cod_old  \
# 872  JULIACA       EMA   -15.47106   -70.17122   M  472CF72C    None
#
#          estado
# 872  AUTOMATICA

# %%
#Este codigo descarga los datos de la estacion definida anteriormente y los combina en un solo archivo excel
# Convertir latitud y longitud a números
stations_data['lat'] = pd.to_numeric(stations_data['lat'], errors='coerce')
stations_data['lon'] = pd.to_numeric(stations_data['lon'], errors='coerce')

lat = stations_data['lat'].tolist()[0]
lon = stations_data['lon'].tolist()[0]
stc = stations_data['estacion'].tolist()[0]
codigo = stations_data['cod'].tolist()[0]
print('codigo', codigo)

print("values", lat, lon, stc)

# Llamar a la función para obtener datos históricos
try:
    resultados = senamhiws_info(codigo, stations_data, '2000-01-01', '2025-09-30', lat, lon, stc)
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# codigo 472CF72C
# values -15.47106 -70.17122 JULIACA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200001&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200002&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200003&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200004&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200005&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200006&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200007&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200008&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200009&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200010&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200011&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200012&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200101&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200102&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200103&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200104&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200105&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200106&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200107&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200108&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200109&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200110&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200111&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200112&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200201&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200202&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200203&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200204&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200205&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200206&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200207&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200208&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200209&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200210&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200211&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200212&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200301&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200302&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200303&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200304&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200305&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200306&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200307&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200308&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200309&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200310&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200311&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200312&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200401&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200402&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200403&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200404&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200405&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200406&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200407&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200408&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200409&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200410&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200411&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200412&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200501&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200502&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200503&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200504&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200505&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200506&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200507&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200508&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200509&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200510&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200511&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200512&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200601&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200602&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200603&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200604&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200605&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200606&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200607&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200608&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200609&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200610&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200611&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200612&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200701&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200702&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200703&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200704&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200705&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200706&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200707&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200708&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200709&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200710&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200711&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200712&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200801&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200802&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200803&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200804&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200805&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200806&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200807&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200808&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200809&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200810&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200811&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200812&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200901&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200902&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200903&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200904&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200905&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200906&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200907&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200908&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200909&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200910&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200911&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=200912&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201001&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201002&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201003&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201004&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201005&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201006&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201007&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201008&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201009&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201010&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201011&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201012&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201101&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201102&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201103&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201104&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201105&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201106&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201107&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201108&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201109&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201110&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201111&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201112&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201201&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201202&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201203&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201204&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201205&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201206&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201207&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201208&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201209&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201210&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201211&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201212&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201301&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201302&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201303&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201304&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201305&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201306&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201307&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201308&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201309&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201310&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201311&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201312&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201401&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201402&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201403&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201404&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201405&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201406&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201407&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201408&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201409&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201410&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201411&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201412&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201501&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201502&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201503&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201504&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201505&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201506&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201507&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201508&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201509&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201510&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201511&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201512&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201601&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201602&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201603&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201604&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201605&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201606&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201607&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201608&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201609&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201610&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201611&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201612&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201701&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201702&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201703&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201704&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201705&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201706&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201707&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201708&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201709&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201710&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201711&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201712&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201801&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201802&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201803&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201804&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201805&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201806&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201807&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201808&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201809&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201810&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201811&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201812&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201901&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201902&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201903&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201904&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201905&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201906&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201907&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201908&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201909&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201910&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201911&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=201912&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202001&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202002&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202003&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202004&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202005&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202006&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202007&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202008&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202009&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202010&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202011&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202012&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202101&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202102&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202103&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202104&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202105&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202106&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202107&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202108&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202109&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202110&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202111&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202112&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202201&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202202&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202203&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202204&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202205&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202206&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202207&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202208&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202209&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202210&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202211&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202212&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202301&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202302&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202303&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202304&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202305&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202306&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202307&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202308&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202309&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202310&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202311&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202312&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202401&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202402&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202403&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202404&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202405&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202406&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202407&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202408&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202409&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202410&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202411&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202412&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202501&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202502&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202503&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202504&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202505&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202506&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202507&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202508&t_e=M&estado=AUTOMATICA
# Descargando datos desde: https://www.senamhi.gob.pe//mapas/mapa-estaciones-2/export.php?estaciones=472CF72C&CBOFiltro=202509&t_e=M&estado=AUTOMATICA
# Datos combinados guardados en: 472CF72C_JULIACA_historico.xlsx

# %% [markdown]
# # <font size = 5 color = 'black'> **Función de Web Scraping para exportar datos historicos de calidad de aire de Lima de las estaciones de SENAMHI**

# %%
pip install --upgrade selenium
# Out:
# Requirement already satisfied: selenium in /usr/local/lib/python3.11/dist-packages (4.34.2)
# Requirement already satisfied: urllib3~=2.5.0 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.5.0->selenium) (2.5.0)
# Requirement already satisfied: trio~=0.30.0 in /usr/local/lib/python3.11/dist-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in /usr/local/lib/python3.11/dist-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.6.15 in /usr/local/lib/python3.11/dist-packages (from selenium) (2025.8.3)
# Requirement already satisfied: typing_extensions~=4.14.0 in /usr/local/lib/python3.11/dist-packages (from selenium) (4.14.1)
# Requirement already satisfied: websocket-client~=1.8.0 in /usr/local/lib/python3.11/dist-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (3.6)
# Requirement already satisfied: outcome in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.11/dist-packages (from trio-websocket~=0.12.2->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.16.0)

# %%
import pandas as pd
# Cargar nombres de estaciones desde archivo Excel
df_estaciones = pd.read_excel("/content/Complemento.xlsx")
dict_cod_a_nombre = dict(zip(df_estaciones['estacion'].astype(str), df_estaciones['est_nombre']))
dict_cod_a_nombre
# Out:
# {'111286': 'CARABAYLLO',
#  '111287': 'PUENTE_PIEDRA',
#  '112192': 'ATE',
#  '112193': 'SAN_BORJA',
#  '112194': 'CAMPO_DE_MARTE',
#  '112208': 'SANTA_ANITA',
#  '112233': 'VILLA_MARIA_DEL_TRIUNFO',
#  '112265': 'SAN_MARTIN_DE_PORRES',
#  '112266': 'HUACHIPA',
#  '112267': 'SAN_JUAN_DE_LURIGANCHO'}

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2025.8.3)

# %%
import pandas as pd
import folium
import re

# Función robusta: convierte DMS a decimal o devuelve el valor si ya es float
def dms_a_decimal(coord):
    if pd.isna(coord):
        return None
    if isinstance(coord, float) or isinstance(coord, int):
        return coord
    coord = str(coord)
    try:
        partes = re.split('[°′″\'"]+', coord.replace('’', '′').replace("'", "′"))
        partes = [p.strip() for p in partes if p.strip()]
        grados = float(partes[0])
        minutos = float(partes[1])
        segundos = float(partes[2])
        signo = -1 if grados < 0 else 1
        return signo * (abs(grados) + minutos / 60 + segundos / 3600)
    except Exception as e:
        print(f"⚠️ Error con coordenada: {coord} → {e}")
        return None

# Cargar el Excel
df_estaciones = pd.read_excel("/content/Complemento.xlsx")

# Convertir latitud y longitud a decimal
df_estaciones['latitud_decimal'] = df_estaciones['y_lat'].apply(dms_a_decimal)
df_estaciones['longitud_decimal'] = df_estaciones['x_lon'].apply(dms_a_decimal)

# Crear el mapa base centrado en Lima
m = folium.Map(location=[-12.0464, -77.0428], zoom_start=10)

# Añadir las estaciones al mapa
for _, row in df_estaciones.iterrows():
    nombre = row['est_nombre']
    codigo = row['estacion']
    lat = row['latitud_decimal']
    lon = row['longitud_decimal']

    folium.Marker(
        location=[lat, lon],
        popup=f"<b>{nombre}</b><br>Código: {codigo}",
        tooltip=nombre,
        icon=folium.Icon(color='green', icon='cloud')
    ).add_to(m)

# Mostrar el mapa
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f903b4cca592413c0517a1c5f0ded38 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f903b4cca592413c0517a1c5f0ded38&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f903b4cca592413c0517a1c5f0ded38 = L.map(
#                 &quot;map_3f903b4cca592413c0517a1c5f0ded38&quot;,
#                 {
#                     center: [-12.0464, -77.0428],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_26dd08b837f50ff73fb1a9222004050f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_26dd08b837f50ff73fb1a9222004050f.addTo(map_3f903b4cca592413c0517a1c5f0ded38);
#
#
#             var marker_5542619691090f3fba63b4658e31b576 = L.marker(
#                 [-11.902194444444445, -77.03363888888889],
#                 {
# }
#             ).addTo(map_3f903b4cca592413c0517a1c5f0ded38);
#
#
#             var icon_ae5048639bcf35cb24ef9d5abdb6a162 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_331e551e43f468fd7d606fc501f2f9c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b903a8369e62a32650ba03663be576f = $(`&lt;div id=&quot;html_5b903a8369e62a32650ba03663be576f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;CARABAYLLO&lt;/b&gt;&lt;br&gt;Código: 111286&lt;/div&gt;`)[0];
#                 popup_331e551e43f468fd7d606fc501f2f9c9.setContent(html_5b903a8369e62a32650ba03663be576f);
#
#
#
#         marker_5542619691090f3fba63b4658e31b576.bindPopup(popup_331e551e43f468fd7d606fc501f2f9c9)
#         ;
#
#
#
#
#             marker_5542619691090f3fba63b4658e31b576.bindTooltip(
#                 `&lt;div&gt;
#                      CARABAYLLO
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_5542619691090f3fba63b4658e31b576.setIcon(icon_ae5048639bcf35cb24ef9d5abdb6a162);
#
#
#             var marker_b118bb73e4c0528104a9caa9d968f138 = L.marker(
#                 [-11.863252777777777, -77.07413333333334],
#                 {
# }
#             ).addTo(map_3f903b4cca592413c0517a1c5f0ded38);
#
#
#             var icon_d471f08147975758ee2e547fb5288832 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fb773b9780518901dd319ff81b931253 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_632b2f98b58f73b0afbc508c71cda7a5 = $(`&lt;div id=&quot;html_632b2f98b58f73b0afbc508c71cda7a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;PUENTE_PIEDRA&lt;/b&gt;&lt;br&gt;Código: 111287&lt;/div&gt;`)[0];
#                 popup_fb773b9780518901dd319ff81b931253.setContent(html_632b2f98b58f73b0afbc508c71cda7a5);
#
#
#
#         marker_b118bb73e4c0528104a9caa9d968f138.bindPopup(popup_fb773b9780518901dd319ff81b931253)
#         ;
#
#
#
#
#             marker_b118bb73e4c0528104a9caa9d968f138.bindTooltip(
#                 `&lt;div&gt;
#                      PUENTE_PIEDRA
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_b118bb73e4c0528104a9caa9d968f138.setIcon(icon_d471f08147975758ee2e547fb5288832);
#
#
#             var marker_5a3ba2db585794da3b8218dd24f32138 = L.marker(
#                 [-12.026049, -76.918563],
#                 {
# }
#             ).addTo(map_3f903b4cca592413c0517a1c5f0ded38);
#
#
#             var icon_9ce28c1cfdf423346f4fc72a85ec74d6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_90d341c1ef5028ab3431332831a90196 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40b18c6743d136ea3c6e2

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
import os
'''
{'111286': 'CARABAYLLO',
 '111287': 'PUENTE_PIEDRA',
 '112192': 'ATE',
 '112193': 'SAN_BORJA',
 '112194': 'CAMPO_DE_MARTE',
 '112208': 'SANTA_ANITA',
 '112233': 'VILLA_MARIA_DEL_TRIUNFO',
 '112265': 'SAN_MARTIN_DE_PORRES',
 '112266': 'HUACHIPA',
 '112267': 'SAN_JUAN_DE_LURIGANCHO'}
 '''


# Estaciones de Lima
estaciones = ["111286", "111287","112192",'112193','112194','112208','112233','112265','112266','112267']

# Cargar nombres de estaciones desde archivo Excel
df_estaciones = pd.read_excel("/content/Complemento.xlsx")
dict_cod_a_nombre = dict(zip(df_estaciones['estacion'].astype(str), df_estaciones['est_nombre']))

# Configuración headless del navegador
options = Options()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome(options=options)

# Crear carpeta de salida
os.makedirs("datos_senamhi", exist_ok=True)

for est in estaciones:
    print(f"📡 Procesando estación {est}...")

    url = f'https://www.senamhi.gob.pe/?p=calidad_del_aire-estadistica&e={est}'
    driver.get(url)

    try:
        WebDriverWait(driver, 15).until(
            EC.element_to_be_clickable((By.XPATH, '/html/body/div[3]/div/div/div[1]/table/tbody/tr[2]/td[6]/a'))
        ).click()

        WebDriverWait(driver, 15).until(
            EC.frame_to_be_available_and_switch_to_it((By.ID, "iframeGraficas"))
        )

        select_conta = Select(WebDriverWait(driver, 10).until(
            EC.presence_of_element_located((By.ID, 'cboConta'))
        ))
        total_conta = len(select_conta.options)

        # Diccionario para guardar series por contaminante
        data_dict = {}

        for pc in range(1, total_conta):
            Select(driver.find_element(By.ID, 'cboConta')).select_by_index(pc)
            time.sleep(1)

            fecha1 = driver.find_element(By.ID, 'datepickerFch1')
            fecha1.clear()
            fecha1.send_keys("12/09/2014")
            fecha1.send_keys(Keys.RETURN)

            WebDriverWait(driver, 10).until(
                EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/form/div[7]/button'))
            ).click()
            time.sleep(6)

            WebDriverWait(driver, 10).until(
                EC.frame_to_be_available_and_switch_to_it((By.XPATH, '/html/body/div[1]/div[2]/iframe'))
            )
            time.sleep(1)

            script_html = driver.find_element(By.XPATH, '/html/body/script[3]').get_attribute('innerHTML')
            partes = script_html.split("{")

            fechas = partes[5].split("categories: [")[1].split("]")[0].replace("'", "").split(",")

            if pc == 4:
                valores = partes[16]
                nombre = partes[15]
            else:
                valores = partes[14]
                nombre = partes[13]

            valores = valores.split("data: [")[1].split("]")[0].split(",")
            nombre = nombre.split("name: '")[1].split("'")[0]

            serie = pd.Series(valores, index=fechas)
            data_dict[nombre] = serie

            print(f"  └── Contaminante '{nombre}' descargado con {len(serie)} registros.")

            driver.switch_to.parent_frame()

        # Combinar todas las series en un solo DataFrame alineado por fecha
        df_final = pd.DataFrame(data_dict)
        df_final.index.name = 'fecha'
        df_final.reset_index(inplace=True)

        # Añadir estación
        estacion_nombre = dict_cod_a_nombre.get(est, "DESCONOCIDA")
        df_final["estacion_codigo"] = est
        df_final["estacion_nombre"] = estacion_nombre

        # Guardar Excel
        nombre_archivo = f"datos_senamhi/{est}_contaminantes.xlsx"
        df_final.to_excel(nombre_archivo, index=False)
        print(f"✅ Archivo generado: {nombre_archivo}")

        # Cerrar ventana emergente
        driver.switch_to.parent_frame()
        WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, '/html/body/div[3]/div/div/div[2]/div/div/div[2]/button'))
        ).click()
        time.sleep(2)

    except Exception as e:
        print(f"  ⚠️ Error en estación {est}: {e}")
        continue

driver.quit()
print("✅ Proceso finalizado.")
# Out:
# 📡 Procesando estación 111286...
#   └── Contaminante 'Material Particulado menor a 10 micras (PM10)' descargado con 71385 registros.
#   └── Contaminante 'Material Particulado menor a 2.5 micras (PM2.5)' descargado con 71385 registros.
#   └── Contaminante 'Dioxido de Azufre (SO2)' descargado con 71385 registros.
#   └── Contaminante 'Oxidos de Nitrogeno (NO2)' descargado con 71385 registros.
#   └── Contaminante 'Ozono Troposferico(O3)' descargado con 71385 registros.
#   └── Contaminante 'Monoxido de Carbono (CO)' descargado con 71385 registros.
# ✅ Archivo generado: datos_senamhi/111286_contaminantes.xlsx
# 📡 Procesando estación 111287...
#   └── Contaminante 'Material Particulado menor a 10 micras (PM10)' descargado con 57895 registros.
#   └── Contaminante 'Material Particulado menor a 2.5 micras (PM2.5)' descargado con 57895 registros.
#   └── Contaminante 'Dioxido de Azufre (SO2)' descargado con 57895 registros.
#   └── Contaminante 'Oxidos de Nitrogeno (NO2)' descargado con 57895 registros.
#   └── Contaminante 'Ozono Troposferico(O3)' descargado con 57895 registros.
#   └── Contaminante 'Monoxido de Carbono (CO)' descargado con 57895 registros.
# ✅ Archivo generado: datos_senamhi/111287_contaminantes.xlsx
# 📡 Procesando estación 112192...
#   └── Contaminante 'Material Particulado menor a 10 micras (PM10)' descargado con 34820 registros.
#   └── Contaminante 'Material Particulado menor a 2.5 micras (PM2.5)' descargado con 34820 registros.
#   └── Contaminante 'Dioxido de Azufre (SO2)' descargado con 34820 registros.
#   └── Contaminante 'Oxidos de Nitrogeno (NO2)' descargado con 34820 registros.
#   └── Contaminante 'Ozono Troposferico(O3)' descargado con 34820 registros.
#   └── Contaminante 'Monoxido de Carbono (CO)' descargado con 34820 registros.
# ✅ Archivo generado: datos_senamhi/112192_contaminantes.xlsx
# 📡 Procesando estación 112193...
#   └── Contaminante 'Material Particulado menor a 10 micras (PM10)' descargado con 77611 registros.
#   └── Contaminante 'Material Particulado menor a 2.5 micras (PM2.5)' descargado con 77611 registros.
#   └── Contaminante 'Dioxido de Azufre (SO2)' descargado con 77611 registros.
#   └── Contaminante 'Oxidos de Nitrogeno (NO2)' descargado con 77611 registros.
#   └── Contaminante 'Ozono Troposferico(O3)' descargado con 77611 registros.
#   └── Contaminante 'Monoxido de Carbono (CO)' descargado con 77611 registros.
# ✅ Archivo generado: datos_senamhi/112193_contaminantes.xlsx
# 📡 Procesando estación 112194...
#   └── Contaminante 'Material Particulado menor a 10 micras (PM10)' descargado con 82944 registros.
#   └── Contaminante 'Material Particulado menor a 2.5 micras (PM2.5)' descargado con 82944 registros.
#   └── Contaminante 'Dioxido de Azufre (SO2)' descargado con 82944 registros.
#   └── Contaminante 'Oxidos de Nitrogeno (NO2)' descargado con 82944 registros.
#   └── Contaminante 'Ozono Troposferico(O3)' descargado con 82944 registros.
#   ⚠️ Error en estación 112194: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/script[3]"}
#   (Session info: chrome=138.0.7204.183); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# #0 0x5c672a9882ca <unknown>
# #1 0x5c672a42f550 <unknown>
# #2 0x5c672a4810f0 <unknown>
# #3 0x5c672a4812e1 <unknown>
# #4 0x5c672a4cf5e4 <unknown>
# #5 0x5c672a4a6bed <unknown>
# #6 0x5c672a4cc9e6 <unknown>
# #7 0x5c672a4a6993 <unknown>
# #8 0x5c672a472d6b <unknown>
# #9 0x5c672a474141 <unknown>
# #10 0x5c672a94d2ab <unknown>
# #11 0x5c672a9510b9 <unknown>
# #12 0x5c672a934139 <unknown>
# #13 0x5c672a951c68 <unknown>
# #14 0x5c672a91860f <unknown>
# #15 0x5c672a9761f8 <unknown>
# #16 0x5c672a9763d6 <unknown>
# #17 0x5c672a9875e6 <unknown>
# #18 0x7d6dd7ec5ac3 <unknown>
#
# 📡 Procesando estación 112208...
#   └── Contaminante 'Material Particulado menor a 10 micras (PM10)' descargado con 83866 registros.
#   └── Contaminante 'Material Particulado menor a 2.5 micras (PM2.5)' descargado con 83866 registros.
#   └── Contaminante 'Dioxido de Azufre (SO2)' descargado con 83866 registros.
#   └── Contaminante 'Oxidos de Nitrogeno (NO2)' descargado con 83866 registros.
#   └── Contaminante 'Ozono Troposferico(O3)' descargado con 83866 registros.
#   └── Contaminante 'Monoxido de Carbono (CO)' descargado con 83866 registros.
# ✅ Archivo generado: datos_senamhi/112208_contaminantes.xlsx
# 📡 Procesando estación 112233...
#   └── Contaminante 'Material Particulado menor a 10 micras (PM10)' descargado con 66541 registros.
#   └── Contaminante 'Material Particulado menor a 2.5 micras (PM2.5)' descargado con 66541 registros.
#   └── Contaminante 'Dioxido de Azufre (SO2)' descargado con 66541 registros.
#   └── Contaminante 'Oxidos de Nitrogeno (NO2)' descargado con 66541 registros.
#   └── Contaminante 'Ozono Troposferico(O3)' descargado con 66541 registros.
#   ⚠️ Error en estación 112233: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/script[3]"}
#   (Session info: chrome=138.0.7204.183); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# #0 0x5c672a9882ca <unknown>
# #1 0x5c672a42f550 <unknown>
# #2 0x5c672a4810f0 <unknown>
# #3 0x5c672a4812e1 <unknown>
# #4 0x5c672a4cf5e4 <unknown>
# #5 0x5c672a4a6bed <unknown>
# #6 0x5c672a4cc9e6 <unknown>
# #7 0x5c672a4a6993 <unknown>
# #8 0x5c672a472d6b <unknown>
# #9 0x5c672a474141 <unknown>
# #10 0x5c672a94d2ab <unknown>
# #11 0x5c672a9510b9 <unknown>
# #12 0x5c672a934139 <unknown>
# #13 0x5c672a951c68 <unknown>
# #14 0x5c672a91860f <unknown>
# #15 0x5c672a9761f8 <unknown>
# #16 0x5c672a9763d6 <unknown>
# #17 0x5c672a9875e6 <unknown>
# #18 0x7d6dd7ec5ac3 <unknown>
#
# 📡 Procesando estación 112265...
#   └── Contaminante 'Material Particulado menor a 10 micras (PM10)' descargado con 157738 registros.
#   └── Contaminante 'Material Particulado menor a 2.5 micras (PM2.5)' descargado con 157738 registros.
#   └── Contaminante 'Dioxido de Azufre (SO2)' descargado con 157738 registros.
#   └── Contaminante 'Oxidos de Nitrogeno (NO2)' descargado con 157738 registros.
#   └── Contaminante 'Ozono Troposferico(O3)' descargado con 157738 registros.
#   └── Contaminante 'Monoxido de Carbono (CO)' descargado con 157738 registros.
# ✅ Archivo generado: datos_senamhi/112265_contaminantes.xlsx
# 📡 Procesando estación 112266...
#   └── Contaminante 'Material Particulado menor a 10 micras (PM10)' descargado con 32319 registros.
#   └── Contaminante 'Material Particulado menor a 2.5 micras (PM2.5)' descargado con 32319 registros.
#   └── Contaminante 'Dioxido de Azufre (SO2)' descargado con 32319 registros.
#   └── Contaminante 'Oxidos de Nitrogeno (NO2)' descargado con 32319 registros.
#   └── Contaminante 'Ozono Troposferico(O3)' descargado con 32319 registros.
#   └── Contaminante 'Monoxido de Carbono (CO)' descargado con 32319 registros.
# ✅ Archivo generado: datos_senamhi/112266_contaminantes.xlsx
# 📡 Procesando estación 112267...
#   └── Contaminante 'Material Particulado menor a 10 micras (PM10)' descargado con 84492 registros.
#   └── Contaminante 'Material Particulado menor a 2.5 micras (PM2.5)' descargado con 84492 registros.
#   └── Contaminante 'Dioxido de Azufre (SO2)' descargado con 84492 registros.
#   └── Contaminante 'Oxidos de Nitrogeno (NO2)' descargado con 84492 registros.
#   └── Contaminante 'Ozono Troposferico(O3)' descargado con 84492 registros.
#   └── Contaminante 'Monoxido de Carbono (CO)' descargado con 84492 registros.
# ✅ Archivo generado: datos_senamhi/112267_contaminantes.xlsx
# ✅ Proceso finalizado.

# %% [markdown]
# ## Prueba de error 1

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
import os
import numpy as np

# Estaciones de Lima
estaciones = ['112194', '112233']

# Cargar nombres de estaciones desde archivo Excel
df_estaciones = pd.read_excel("/content/Complemento.xlsx")
dict_cod_a_nombre = dict(zip(df_estaciones['estacion'].astype(str), df_estaciones['est_nombre']))

# Configuración headless del navegador
options = Options()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome(options=options)

# Crear carpeta de salida
os.makedirs("datos_senamhi", exist_ok=True)

for est in estaciones:
    print(f"\n📡 Procesando estación {est}...")

    url = f'https://www.senamhi.gob.pe/?p=calidad_del_aire-estadistica&e={est}'
    driver.get(url)

    try:
        # Abrir visor
        WebDriverWait(driver, 15).until(
            EC.element_to_be_clickable((By.XPATH, '/html/body/div[3]/div/div/div[1]/table/tbody/tr[2]/td[6]/a'))
        ).click()

        # Cambiar a iframe principal
        WebDriverWait(driver, 15).until(
            EC.frame_to_be_available_and_switch_to_it((By.ID, "iframeGraficas"))
        )

        select_conta = Select(WebDriverWait(driver, 10).until(
            EC.presence_of_element_located((By.ID, 'cboConta'))
        ))
        total_conta = len(select_conta.options)

        data_dict = {}

        for pc in range(1, total_conta):
            try:
                selector = Select(driver.find_element(By.ID, 'cboConta'))
                selector.select_by_index(pc)
                contaminante_nombre_actual = selector.options[pc].text.strip()
                print(f"🔍 Intentando descargar: '{contaminante_nombre_actual}'")
                time.sleep(1)

                fecha1 = driver.find_element(By.ID, 'datepickerFch1')
                fecha1.clear()
                fecha1.send_keys("12/09/2014")
                fecha1.send_keys(Keys.RETURN)

                WebDriverWait(driver, 10).until(
                    EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/form/div[7]/button'))
                ).click()
                time.sleep(6)

                WebDriverWait(driver, 10).until(
                    EC.frame_to_be_available_and_switch_to_it((By.XPATH, '/html/body/div[1]/div[2]/iframe'))
                )
                time.sleep(1)

                # Buscar script dinámicamente
                scripts = driver.find_elements(By.TAG_NAME, 'script')
                script_html = None
                for s in scripts:
                    html = s.get_attribute('innerHTML')
                    if "Highcharts.chart" in html:
                        script_html = html
                        break

                if script_html is None:
                    print(f"  ⚠️ Contaminante '{contaminante_nombre_actual}' no tiene gráfico ni datos.")
                    driver.switch_to.parent_frame()
                    continue

                partes = script_html.split("{")
                fechas = partes[5].split("categories: [")[1].split("]")[0].replace("'", "").split(",")

                if pc == 4:
                    valores = partes[16]
                    nombre = partes[15]
                else:
                    valores = partes[14]
                    nombre = partes[13]

                valores = valores.split("data: [")[1].split("]")[0].split(",")
                nombre = nombre.split("name: '")[1].split("'")[0]

                # Conversión robusta a float
                valores = [float(v.strip()) if v.strip().lower() not in ['null', ''] else np.nan for v in valores]

                serie = pd.Series(valores, index=fechas)

                if not serie.dropna().empty:
                    data_dict[nombre] = serie
                    print(f"  └── Contaminante '{nombre}' descargado con {serie.count()} valores válidos.")
                else:
                    print(f"  ⚠️ Contaminante '{nombre}' ignorado (solo NaN).")

                driver.switch_to.parent_frame()

            except Exception as err:
                print(f"  ⚠️ Error procesando contaminante '{contaminante_nombre_actual}': {err}")
                try:
                    driver.switch_to.parent_frame()
                except:
                    pass
                continue

        if not data_dict:
            print(f"  ⚠️ No se descargaron contaminantes válidos para estación {est}")
            continue

        df_final = pd.DataFrame(data_dict)
        df_final.index.name = 'fecha'
        df_final.reset_index(inplace=True)

        estacion_nombre = dict_cod_a_nombre.get(est, "DESCONOCIDA")
        df_final["estacion_codigo"] = est
        df_final["estacion_nombre"] = estacion_nombre

        nombre_archivo = f"datos_senamhi/{est}_contaminantes.xlsx"
        df_final.to_excel(nombre_archivo, index=False)
        print(f"✅ Archivo generado: {nombre_archivo}")

        # Cerrar modal
        driver.switch_to.parent_frame()
        WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, '/html/body/div[3]/div/div/div[2]/div/div/div[2]/button'))
        ).click()
        time.sleep(2)

    except Exception as e:
        print(f"❌ Error en estación {est}: {e}")
        continue

driver.quit()
print("\n✅ Proceso finalizado.")
# Out:
# 📡 Procesando estación 112194...
# 🔍 Intentando descargar: 'N_PM10'
#   └── Contaminante 'Material Particulado menor a 10 micras (PM10)' descargado con 70842 valores válidos.
# 🔍 Intentando descargar: 'N_PM25'
#   └── Contaminante 'Material Particulado menor a 2.5 micras (PM2.5)' descargado con 69471 valores válidos.
# 🔍 Intentando descargar: 'N_SO2'
#   └── Contaminante 'Dioxido de Azufre (SO2)' descargado con 47642 valores válidos.
# 🔍 Intentando descargar: 'N_NO2'
#   └── Contaminante 'Oxidos de Nitrogeno (NO2)' descargado con 68677 valores válidos.
# 🔍 Intentando descargar: 'N_O3'
#   └── Contaminante 'Ozono Troposferico(O3)' descargado con 52493 valores válidos.
# 🔍 Intentando descargar: 'N_CO'
#   ⚠️ Contaminante 'N_CO' no tiene gráfico ni datos.
# ✅ Archivo generado: datos_senamhi/112194_contaminantes.xlsx
#
# 📡 Procesando estación 112233...
# 🔍 Intentando descargar: 'N_PM10'
#   └── Contaminante 'Material Particulado menor a 10 micras (PM10)' descargado con 63244 valores válidos.
# 🔍 Intentando descargar: 'N_PM25'
#   └── Contaminante 'Material Particulado menor a 2.5 micras (PM2.5)' descargado con 57967 valores válidos.
# 🔍 Intentando descargar: 'N_SO2'
#   └── Contaminante 'Dioxido de Azufre (SO2)' descargado con 52525 valores válidos.
# 🔍 Intentando descargar: 'N_NO2'
#   └── Contaminante 'Oxidos de Nitrogeno (NO2)' descargado con 57100 valores válidos.
# 🔍 Intentando descargar: 'N_O3'
#   └── Contaminante 'Ozono Troposferico(O3)' descargado con 41097 valores válidos.
# 🔍 Intentando descargar: 'N_CO'
#   ⚠️ Contaminante 'N_CO' no tiene gráfico ni datos.
# ✅ Archivo generado: datos_senamhi/112233_contaminantes.xlsx
#
# ✅ Proceso finalizado.

# %% [markdown]
# ## Prueba de error 2

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
import os
import numpy as np

# Estaciones de Lima
estaciones = ['112233']

# Cargar nombres de estaciones desde archivo Excel
df_estaciones = pd.read_excel("/content/Complemento.xlsx")
dict_cod_a_nombre = dict(zip(df_estaciones['estacion'].astype(str), df_estaciones['est_nombre']))

# Configuración headless del navegador
options = Options()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome(options=options)

# Crear carpeta de salida
os.makedirs("datos_senamhi", exist_ok=True)

for est in estaciones:
    print(f"\n📡 Procesando estación {est}...")

    url = f'https://www.senamhi.gob.pe/?p=calidad_del_aire-estadistica&e={est}'
    driver.get(url)

    try:
        # Abrir visor
        WebDriverWait(driver, 15).until(
            EC.element_to_be_clickable((By.XPATH, '/html/body/div[3]/div/div/div[1]/table/tbody/tr[2]/td[6]/a'))
        ).click()

        # Cambiar a iframe principal
        WebDriverWait(driver, 15).until(
            EC.frame_to_be_available_and_switch_to_it((By.ID, "iframeGraficas"))
        )

        select_conta = Select(WebDriverWait(driver, 10).until(
            EC.presence_of_element_located((By.ID, 'cboConta'))
        ))
        total_conta = len(select_conta.options)

        data_dict = {}

        for pc in range(1, total_conta):
            try:
                selector = Select(driver.find_element(By.ID, 'cboConta'))
                selector.select_by_index(pc)
                contaminante_nombre_actual = selector.options[pc].text.strip()
                print(f"🔍 Intentando descargar: '{contaminante_nombre_actual}'")
                time.sleep(1)

                fecha1 = driver.find_element(By.ID, 'datepickerFch1')
                fecha1.clear()
                fecha1.send_keys("12/09/2014")
                fecha1.send_keys(Keys.RETURN)

                WebDriverWait(driver, 10).until(
                    EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/form/div[7]/button'))
                ).click()
                time.sleep(6)

                WebDriverWait(driver, 10).until(
                    EC.frame_to_be_available_and_switch_to_it((By.XPATH, '/html/body/div[1]/div[2]/iframe'))
                )
                time.sleep(1)

                # Buscar script dinámicamente
                scripts = driver.find_elements(By.TAG_NAME, 'script')
                script_html = None
                for s in scripts:
                    html = s.get_attribute('innerHTML')
                    if "Highcharts.chart" in html:
                        script_html = html
                        break

                # 👇 Si no hay gráfico
                if script_html is None:
                    if contaminante_nombre_actual.strip().upper() == "N_CO":
                        print(f"  ⏭️ Contaminante '{contaminante_nombre_actual}' omitido (sin gráfico y es N_CO).")
                    else:
                        print(f"  ⚠️ Contaminante '{contaminante_nombre_actual}' no tiene gráfico ni datos.")
                    driver.switch_to.parent_frame()
                    continue

                partes = script_html.split("{")
                fechas = partes[5].split("categories: [")[1].split("]")[0].replace("'", "").split(",")

                if pc == 4:
                    valores = partes[16]
                    nombre = partes[15]
                else:
                    valores = partes[14]
                    nombre = partes[13]

                valores = valores.split("data: [")[1].split("]")[0].split(",")
                nombre = nombre.split("name: '")[1].split("'")[0]

                # Conversión robusta a float
                valores = [float(v.strip()) if v.strip().lower() not in ['null', ''] else np.nan for v in valores]
                serie = pd.Series(valores, index=fechas)

                # ✅ OMITE últimas 3 horas del día actual para 'N_CO'
                if nombre.strip().upper() == "N_CO":
                    fechas_np = pd.to_datetime(serie.index, errors='coerce', dayfirst=True)
                    hoy = pd.Timestamp.now().date()
                    if any(f.date() == hoy for f in fechas_np[-3:]):
                        print(f"  ⚠️ Omitiendo últimas 3 horas del día actual para contaminante '{nombre}'")
                        serie = serie[:-3]  # Quita últimas 3 filas

                if not serie.dropna().empty:
                    data_dict[nombre] = serie
                    print(f"  └── Contaminante '{nombre}' descargado con {serie.count()} valores válidos.")
                else:
                    print(f"  ⚠️ Contaminante '{nombre}' ignorado (solo NaN).")

                driver.switch_to.parent_frame()

            except Exception as err:
                print(f"  ⚠️ Error procesando contaminante '{contaminante_nombre_actual}': {err}")
                try:
                    driver.switch_to.parent_frame()
                except:
                    pass
                continue

        if not data_dict:
            print(f"  ⚠️ No se descargaron contaminantes válidos para estación {est}")
            continue

        df_final = pd.DataFrame(data_dict)
        df_final.index.name = 'fecha'
        df_final.reset_index(inplace=True)

        estacion_nombre = dict_cod_a_nombre.get(est, "DESCONOCIDA")
        df_final["estacion_codigo"] = est
        df_final["estacion_nombre"] = estacion_nombre

        nombre_archivo = f"datos_senamhi/{est}_contaminantes.xlsx"
        df_final.to_excel(nombre_archivo, index=False)
        print(f"✅ Archivo generado: {nombre_archivo}")

        # Cerrar modal
        driver.switch_to.parent_frame()
        WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, '/html/body/div[3]/div/div/div[2]/div/div/div[2]/button'))
        ).click()
        time.sleep(2)

    except Exception as e:
        print(f"❌ Error en estación {est}: {e}")
        continue

driver.quit()
print("\n✅ Proceso finalizado.")
# Out:
# 📡 Procesando estación 112233...
# 🔍 Intentando descargar: 'N_PM10'
#   └── Contaminante 'Material Particulado menor a 10 micras (PM10)' descargado con 63243 valores válidos.
# 🔍 Intentando descargar: 'N_PM25'
#   └── Contaminante 'Material Particulado menor a 2.5 micras (PM2.5)' descargado con 57966 valores válidos.
# 🔍 Intentando descargar: 'N_SO2'
#   └── Contaminante 'Dioxido de Azufre (SO2)' descargado con 52524 valores válidos.
# 🔍 Intentando descargar: 'N_NO2'
#   └── Contaminante 'Oxidos de Nitrogeno (NO2)' descargado con 57099 valores válidos.
# 🔍 Intentando descargar: 'N_O3'
#   └── Contaminante 'Ozono Troposferico(O3)' descargado con 41096 valores válidos.
# 🔍 Intentando descargar: 'N_CO'
#   ⏭️ Contaminante 'N_CO' omitido (sin gráfico y es N_CO).
# ✅ Archivo generado: datos_senamhi/112233_contaminantes.xlsx
#
# ✅ Proceso finalizado.
